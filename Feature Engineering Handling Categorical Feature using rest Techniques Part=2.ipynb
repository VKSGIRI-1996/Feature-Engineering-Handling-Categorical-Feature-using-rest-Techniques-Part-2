# %% [markdown]
# # Ordinal Number Encoding
# target- convert categorical to integer

# %%
import datetime

# %%
today_date =datetime.datetime.today()

# %%
today_date
# Out:
# datetime.datetime(2021, 1, 5, 23, 59, 16, 60842)

# %%
today_date-datetime.timedelta(2)
# Out:
# datetime.datetime(2021, 1, 3, 23, 59, 16, 60842)

# %%
###List Comprehension
days = [today_date-datetime.timedelta(x) for x in range(0,15)]

# %%
import pandas as pd
data = pd.DataFrame(days)
data.columns=['Day']

# %%
data.head()
# Out:
#                          Day
# 0 2021-01-05 23:59:16.060842
# 1 2021-01-04 23:59:16.060842
# 2 2021-01-03 23:59:16.060842
# 3 2021-01-02 23:59:16.060842
# 4 2021-01-01 23:59:16.060842

# %%
data['weekday'] = data['Day'].dt.weekday_name
data.head()
# Out:
#                          Day   weekday
# 0 2021-01-05 23:59:16.060842   Tuesday
# 1 2021-01-04 23:59:16.060842    Monday
# 2 2021-01-03 23:59:16.060842    Sunday
# 3 2021-01-02 23:59:16.060842  Saturday
# 4 2021-01-01 23:59:16.060842    Friday

# %%
data['Day'].dt.day
# Out:
# 0      5
# 1      4
# 2      3
# 3      2
# 4      1
# 5     31
# 6     30
# 7     29
# 8     28
# 9     27
# 10    26
# 11    25
# 12    24
# 13    23
# 14    22
# Name: Day, dtype: int64

# %%
dict = {'Monday':1, 'Tuesday':2,'Wednesday':3, 'Thursday':4,'Friday':5, 'Saturday':6, 'Sunday':7}

# %%
dict
# Out:
# {'Monday': 1,
#  'Tuesday': 2,
#  'Wednesday': 3,
#  'Thursday': 4,
#  'Friday': 5,
#  'Saturday': 6,
#  'Sunday': 7}

# %%
data['weekday_ordinal'] = data['weekday'].map(dict)

# %%
data
# Out:
#                           Day    weekday  weekday_ordinal
# 0  2021-01-05 23:59:16.060842    Tuesday                2
# 1  2021-01-04 23:59:16.060842     Monday                1
# 2  2021-01-03 23:59:16.060842     Sunday                7
# 3  2021-01-02 23:59:16.060842   Saturday                6
# 4  2021-01-01 23:59:16.060842     Friday                5
# 5  2020-12-31 23:59:16.060842   Thursday                4
# 6  2020-12-30 23:59:16.060842  Wednesday                3
# 7  2020-12-29 23:59:16.060842    Tuesday                2
# 8  2020-12-28 23:59:16.060842     Monday                1
# 9  2020-12-27 23:59:16.060842     Sunday                7
# 10 2020-12-26 23:59:16.060842   Saturday                6
# 11 2020-12-25 23:59:16.060842     Friday                5
# 12 2020-12-24 23:59:16.060842   Thursday                4
# 13 2020-12-23 23:59:16.060842  Wednesday                3
# 14 2020-12-22 23:59:16.060842    Tuesday                2

# %% [markdown]
# #    ## Count Or Frequency encoding

# %%
train_set = pd.read_csv("adult.csv",header=None,index_col=None)
train_set.head(10)
# Out:
#     0                 1       2             3                4   \
# 0  age         workclass  fnlwgt     education  educational-num
# 1   25           Private  226802          11th                7
# 2   38           Private   89814       HS-grad                9
# 3   28         Local-gov  336951    Assoc-acdm               12
# 4   44           Private  160323  Some-college               10
# 5   18                 ?  103497  Some-college               10
# 6   34           Private  198693          10th                6
# 7   29                 ?  227026       HS-grad                9
# 8   63  Self-emp-not-inc  104626   Prof-school               15
# 9   24           Private  369667  Some-college               10
#
#                    5                  6              7      8       9   \
# 0      marital-status         occupation   relationship   race  gender
# 1       Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
train_set[1].unique()
# Out:
# array(['workclass', 'Private', 'Local-gov', '?', 'Self-emp-not-inc',
#        'Federal-gov', 'State-gov', 'Self-emp-inc', 'Without-pay',
#        'Never-worked'], dtype=object)

# %%
len(train_set[1].unique())
# Out:
# 10

# %%
train_set.head(10)
# Out:
#     0                 1       2             3                4   \
# 0  age         workclass  fnlwgt     education  educational-num
# 1   25           Private  226802          11th                7
# 2   38           Private   89814       HS-grad                9
# 3   28         Local-gov  336951    Assoc-acdm               12
# 4   44           Private  160323  Some-college               10
# 5   18                 ?  103497  Some-college               10
# 6   34           Private  198693          10th                6
# 7   29                 ?  227026       HS-grad                9
# 8   63  Self-emp-not-inc  104626   Prof-school               15
# 9   24           Private  369667  Some-college               10
#
#                    5                  6              7      8       9   \
# 0      marital-status         occupation   relationship   race  gender
# 1       Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
columns=[1,3,5,6,7,8,9,13]

# %%
train_set = train_set[columns]

# %%
train_set.columns=['Employment', 'Degree','Status', 'Designaton', 'Family_job', 'Race', 'Sex', 'Country' ]

# %%
train_set.head()
# Out:
#   Employment        Degree              Status         Designaton  \
# 0  workclass     education      marital-status         occupation
# 1    Private          11th       Never-married  Machine-op-inspct
# 2    Private       HS-grad  Married-civ-spouse    Farming-fishing
# 3  Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 4    Private  Some-college  Married-civ-spouse  Machine-op-inspct
#
#      Family_job   Race     Sex         Country
# 0  relationship   race  gender  native-country
# 1     Own-child  Black    Male   United-States
# 2       Husband  White    Male   United-States
# 3       Husband  White    Male   United-States
# 4       Husband  Black    Male   United-States

# %%
for feature in train_set.columns[:]:
    print(feature,":", len(train_set[feature].unique()),'labels')
# Out:
# Employment : 10 labels
# Degree : 17 labels
# Status : 8 labels
# Designaton : 16 labels
# Family_job : 7 labels
# Race : 6 labels
# Sex : 3 labels
# Country : 43 labels

# %%
train_set['Country'].value_counts().to_dict()
# Out:
# {'United-States': 43832,
#  'Mexico': 951,
#  '?': 857,
#  'Philippines': 295,
#  'Germany': 206,
#  'Puerto-Rico': 184,
#  'Canada': 182,
#  'El-Salvador': 155,
#  'India': 151,
#  'Cuba': 138,
#  'England': 127,
#  'China': 122,
#  'South': 115,
#  'Jamaica': 106,
#  'Italy': 105,
#  'Dominican-Republic': 103,
#  'Japan': 92,
#  'Guatemala': 88,
#  'Poland': 87,
#  'Vietnam': 86,
#  'Columbia': 85,
#  'Haiti': 75,
#  'Portugal': 67,
#  'Taiwan': 65,
#  'Iran': 59,
#  'Nicaragua': 49,
#  'Greece': 49,
#  'Peru': 46,
#  'Ecuador': 45,
#  'France': 38,
#  'Ireland': 37,
#  'Hong': 30,
#  'Thailand': 30,
#  'Cambodia': 28,
#  'Trinadad&Tobago': 27,
#  'Laos': 23,
#  'Outlying-US(Guam-USVI-etc)': 23,
#  'Yugoslavia': 23,
#  'Scotland': 21,
#  'Honduras': 20,
#  'Hungary': 19,
#  'Holand-Netherlands': 1,
#  'native-country': 1}

# %%
country_map = train_set['Country'].value_counts()

# %%
train_set['Country'] = train_set['Country'].map(country_map)

# %%
train_set.head(40)
# Out:
#           Employment        Degree              Status         Designaton  \
# 0          workclass     education      marital-status         occupation
# 1            Private          11th       Never-married  Machine-op-inspct
# 2            Private       HS-grad  Married-civ-spouse    Farming-fishing
# 3          Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 4            Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 5                  ?  Some-college       Never-married                  ?
# 6            Private          10th       Never-married      Other-service
# 7                  ?       HS-grad       Never-married                  ?
# 8   Self-emp-not-inc   Prof-school  Married-civ-spouse     Prof-specialty
# 9            Private  Some-college       Never-married      Other-service
# 10           Private       7th-8th  Married-civ-spouse       Craft-repair
# 11           Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# ...

# %% [markdown]
# ##Advantage
# 1.Easy to Use
# 2.Not increasing feature space
# ##Disadvatage
# 1.provide same weight if the frequencies are same

# %% [markdown]
# # Target Guided Ordinal Encoding
# 1.Ordering the labels according to the target
# 2.Replace the labels by the joint probability of being 1 or 0

# %%
import pandas as pd
df=pd.read_csv('titanic.csv', usecols=['Cabin', 'Survived'])
df.head()
# Out:
#    Survived Cabin
# 0         0   NaN
# 1         1   C85
# 2         1   NaN
# 3         1  C123
# 4         0   NaN

# %%
df['Cabin'].fillna('Missing', inplace=True)

# %%
df.head(10)
# Out:
#    Survived    Cabin
# 0         0  Missing
# 1         1      C85
# 2         1  Missing
# 3         1     C123
# 4         0  Missing
# 5         0  Missing
# 6         0      E46
# 7         0  Missing
# 8         1  Missing
# 9         1  Missing

# %%
df['Cabin'].astype(str).str[0]
# Out:
# 0      M
# 1      C
# 2      M
# 3      C
# 4      M
# 5      M
# 6      E
# 7      M
# 8      M
# 9      M
# 10     G
# 11     C
# 12     M
# 13     M
# 14     M
# 15     M
# 16     M
# 17     M
# 18     M
# 19     M
# 20     M
# 21     D
# 22     M
# 23     A
# 24     M
# 25     M
# 26     M
# 27     C
# 28     M
# 29     M
#       ..
# 861    M
# 862    D
# 863    M
# 864    M
# 865    M
# 866    M
# 867    A
# 868    M
# 869    M
# 870    M
# 871    D
# 872    B
# 873    M
# 874    M
# 875    M
# 876    M
# 877    M
# 878    M
# 879    C
# 880    M
# 881    M
# 882    M
# 883    M
# 884    M
# 885    M
# 886    M
# 887    B
# 888    M
# 889    C
# 890    M
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin']=df['Cabin'].astype(str).str[0]

# %%
df.Cabin.unique()
# Out:
# array(['M', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
df.groupby(['Cabin'])['Survived'].mean()
# Out:
# Cabin
# A    0.466667
# B    0.744681
# C    0.593220
# D    0.757576
# E    0.750000
# F    0.615385
# G    0.500000
# M    0.299854
# T    0.000000
# Name: Survived, dtype: float64

# %%
df.groupby(['Cabin'])['Survived'].mean().sort_values()
# Out:
# Cabin
# T    0.000000
# M    0.299854
# A    0.466667
# G    0.500000
# C    0.593220
# F    0.615385
# B    0.744681
# E    0.750000
# D    0.757576
# Name: Survived, dtype: float64

# %%
df.groupby(['Cabin'])['Survived'].mean().sort_values().index
# Out:
# Index(['T', 'M', 'A', 'G', 'C', 'F', 'B', 'E', 'D'], dtype='object', name='Cabin')

# %%
ordinal_labels=df.groupby(['Cabin'])['Survived'].mean().sort_values().index
ordinal_labels
# Out:
# Index(['T', 'M', 'A', 'G', 'C', 'F', 'B', 'E', 'D'], dtype='object', name='Cabin')

# %%
ordinal_labels2={k:i for i,k in enumerate(ordinal_labels,0)}
ordinal_labels2
# Out:
# {'T': 0, 'M': 1, 'A': 2, 'G': 3, 'C': 4, 'F': 5, 'B': 6, 'E': 7, 'D': 8}

# %%
df['Cabin_ordinal_labels']=df['Cabin'].map(ordinal_labels2)
df.head()
df
# Out:
#      Survived Cabin  Cabin_ordinal_labels  mean_ordinal_encode
# 0           0     M                     1             0.299854
# 1           1     C                     4             0.593220
# 2           1     M                     1             0.299854
# 3           1     C                     4             0.593220
# 4           0     M                     1             0.299854
# 5           0     M                     1             0.299854
# 6           0     E                     7             0.750000
# 7           0     M                     1             0.299854
# 8           1     M                     1             0.299854
# 9           1     M                     1             0.299854
# 10          1     G                     3             0.500000
# 11          1     C                     4             0.593220
# 12          0     M                     1             0.299854
# 13          0     M                     1             0.299854
# ...

# %%
## Now we can drop 'Cabin' Column
df1=df.drop('Cabin',axis=1)

# %%
df1.head()
# Out:
#    Survived  Cabin_ordinal_labels  mean_ordinal_encode
# 0         0                     1             0.299854
# 1         1                     4             0.593220
# 2         1                     1             0.299854
# 3         1                     4             0.593220
# 4         0                     1             0.299854

# %%
df.head()
# Out:
#    Survived Cabin  Cabin_ordinal_labels  mean_ordinal_encode
# 0         0     M                     1             0.299854
# 1         1     C                     4             0.593220
# 2         1     M                     1             0.299854
# 3         1     C                     4             0.593220
# 4         0     M                     1             0.299854

# %% [markdown]
# # Mean Encoding

# %%
df.groupby(['Cabin'])['Survived'].mean().to_dict()
# Out:
# {'A': 0.4666666666666667,
#  'B': 0.7446808510638298,
#  'C': 0.5932203389830508,
#  'D': 0.7575757575757576,
#  'E': 0.75,
#  'F': 0.6153846153846154,
#  'G': 0.5,
#  'M': 0.29985443959243085,
#  'T': 0.0}

# %%
mean_ordinal = df.groupby(['Cabin'])['Survived'].mean().to_dict()

# %%
df['mean_ordinal_encode']=df['Cabin'].map(mean_ordinal)
df.head()
# Out:
#    Survived Cabin  Cabin_ordinal_labels  mean_ordinal_encode
# 0         0     M                     1             0.299854
# 1         1     C                     4             0.593220
# 2         1     M                     1             0.299854
# 3         1     C                     4             0.593220
# 4         0     M                     1             0.299854
